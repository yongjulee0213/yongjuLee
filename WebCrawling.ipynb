# %%
import requests
from bs4 import BeautifulSoup

# %%
review_data=[]
pagenumber=1
while len(review_data)<=1000:
  URL=f"https://movie.naver.com/movie/point/af/list.naver?&page={pagenumber}"
  response=requests.get(URL)#URL얻어오기
  soup=BeautifulSoup(response.text, 'html.parser')#response.txt로 저장 html 파서 이용하기

  page_one=soup.find_all(name='td',attrs={'class':'title'}) #한칸씩 나오는거 확인

  for review in page_one:
    sentence=review.find(name='a',attrs={'class':'report'}).get("onclick").split("', '")[2]
    if sentence !="":#리뷰가 있어야 동작
      movie=review.find(name='a',attrs={'class':'movie color_b'}).string
      score=int(review.find(name='em').string)
      review_data.append([movie,sentence,score])
  pagenumber+1

# %% [markdown]
# 크롤링 소요 시간 : 1m 7s

# %%
print(len(review_data)) #데이터 수 확인
# Out:
# 1008

# %%
print(review_data)
# Out:
# [['스마일', '기괴한 미소를 지으며 자신의 눈 앞에서 목숨을 끊는 환자를 목격한 정신과 의사 로즈. 일상을 덮친 공포에 발버둥치던 로즈는 이전에도 자신과 같은 일을 겪은 사람들이 있었고 그들 모두 끔찍한 죽음을 피할 수 없었다는 사실을 알게 된다.', 10], ['티켓 투 파라다이스', '이쁜 풍경에 발리 마려워지는 영화뻔한 로코물이라지만 뭐 어차피현실 우리네 사랑도 다 뻔한 거 아니냐며“좋은건 뒤로 미루면 안되지 “마지막 엔딩 장면이 넘 멋있었다크레딧 올라갈 때 촬영 비하인드 쿠키는 더 꿀잼', 8], ['대무가', '완전 쿨하고 힙하당', 10], ['인생은 아름다워', '기가막힌 연출이고 류승룡 염정화 아역배우 조연 다 연기가 너무 좋았어요 존경합니다진한 눈물 흘리게해주고 많은걸 느꼈어요', 9], ['함정', '마동석님 멋있었는데 약간 잔인했었어요ㅠㅠ', 6], ['수색자', '전방 격오지에서 복무한 사람들은 어이가 없어서 헛웃음이 날 영화입니다.', 1], ['내안의 그놈', '이건 꼭 봐라 진짜 대작이다', 10], ['천문: 하늘에 묻는다', '너무 슬퍼요... 가슴이 먹먹해서 잠 다 잤어요ㅠ', 10], ['스마일', '기괴한 미소를 지으며 자신의 눈 앞에서 목숨을 끊는 환자를 목격한 정신과 의사 로즈. 일상을 덮친 공포에 발버둥치던 로즈는 이전에도 자신과 같은 일을 겪은 사람들이 있었고 그들 모두 끔찍한 죽음을 피할 수 없었다는 사실을 알게 된다.', 10], ['티켓 투 파라다이스', '이쁜 풍경에 발리 마려워지는 영화뻔한 로코물이라지만 뭐 어차피현실 우리네 사랑도 다 뻔한 거 아니냐며“좋은건 뒤로 미루면 안되지 “마지막 엔딩 장면이 넘 멋있었다크레딧 올라갈 때 촬영 비하인드 쿠키는 더 꿀잼', 8], ['대무가', '완전 쿨하고 힙하당', 10], ['인생은 아름다워', '기가막힌 연출이고 류승룡 염정화 아역배우 조연 다 연기가 너무 좋았어요 존경합니다진한 눈물 흘리게해주고 많은걸 느꼈어요', 9], ['함정', '마동석님 멋있었는데 약간 잔인했었어요ㅠㅠ', 6], ['수색자', '전방 격오지에서 복무한 사람들은 어이가 없어서 헛웃음이 날 영화입니다.', 1], ['내안의 그놈', '이건 꼭 봐라 진짜 대작이다', 10], ['천문: 하늘에 묻는다', '너무 슬퍼요... 가슴이 먹먹해서 잠 다 잤어요ㅠ', 10], ['스마일', '기괴한 미소를 지으며 자신의 눈 앞에서 목숨을 끊는 환자를 목격한 정신과 의사 로즈. 일상을 덮친 공포에 발버둥치던 로즈는 이전에도 자신과 같은 일을 겪은 사람들이 있었고 그들 모두 끔찍한 죽음을 피할 수 없었다는 사실을 알게 된다.', 10], ['티켓 투 파라다이스', '이쁜 풍경에 발리 마려워지는 영화뻔한 로코물이라지만 뭐 어차피현실 우리네 사랑도 다 뻔한 거 아니냐며“좋은건 뒤로 미루면 안되지 “마지막 엔딩 장면이 넘 멋있었다크레딧 올라갈 때 촬영 비하인드 쿠키는 더 꿀잼', 8], ['대무가', '완전 쿨하고 힙하당', 10], ['인생은 아름다워', '기가막힌 연출이고 류승룡 염정화 아역배우 조연 다 연기가 너무 좋았어요 존경합니다진한 눈물 흘리게해주고 많은걸 느꼈어요', 9], ['함정', '마동석님 멋있었는데 약간 잔인했었어요ㅠㅠ', 6], ['수색자', '전방 격오지에서 복무한 사람들은 어이가 없어서 헛웃음이 날 영화입니다.', 1], ['내안의 그놈', '이건 꼭 봐라 진짜 대작이다', 10], ['천문: 하늘에 묻는다', '너무 슬퍼요... 가슴이 먹먹해서 잠 다 잤어요ㅠ', 10], ['스마일', '기괴한 미소를 지으며 자신의 눈 앞에서 목숨을 끊는 환자를 목격한 정신과 의사 로즈. 일상을 덮친 공포에 발버둥치던 로즈는 이전에도 자신과 같은 일을 겪은 사람들이 있었고 그들 모두 끔찍한 죽음을 피할 수 없었다는 사실을 알게 된다.', 10], ['티켓 투 파라다이스', '이쁜 풍경에 발리 마려워지는 영화뻔한 로코물이라지만 뭐 어차피현실 우리네 사랑도 다 뻔한 거 아니냐며“좋은건 뒤로 미루면 안되지 “마지막 엔딩 장면이 넘 멋있었다크레딧 올라갈 때 촬영 비하인드 쿠키는 더 꿀잼', 8], ['대무가', '완전 쿨하고 힙하당', 10], ['인생은 아름다워', '기가막힌 연출이고 류승룡 염정화 아역배우 조연 다 연기가 너무 좋았어요 존경합니다진한 눈물 흘리게해주고 많은걸 느꼈어요', 9], ['함정', '마동석님 멋있었는데 약간 잔인했었어요ㅠㅠ', 6], ['수색자', '전방 격오지에서 복무한 사람들은 어이가 없어서 헛웃음이 날 영화입니다.', 1], ['내안의 그놈', '이건 꼭 봐라 진짜 대작이다', 10], ['천문: 하늘에 묻는다', '너무 슬퍼요... 가슴이 먹먹해서 잠 다 잤어요ㅠ', 10], ['스마일', '기괴한 미소를 지으며 자신의 눈 앞에서 목숨을 끊는 환자를 목격한 정신과 의사 로즈. 일상을 덮친 공포에 발버둥치던 로즈는 이전에도 자신과 같은 일을 겪은 사람들이 있었고 그들 모두 끔찍한 죽음을 피할 수 없었다는 사실을 알게 된다.', 10], ['티켓 투 파라다이스', '이쁜 풍경에 발리 마려워지는 영화뻔한 로코물이라지만 뭐 어차피현실 우리네 사랑도 다 뻔한 거 아니냐며“좋은건 뒤로 미루면 안되지 “마지막 엔딩 장면이 넘 멋있었다크레딧 올라갈 때 촬영 비하인드 쿠키는 더 꿀잼', 8], ['대무가', '완전 쿨하고 힙하당', 10], ['인생은 아름다워', '기가막힌 연출이고 류승룡 염정화 아역배우 조연 다 연기가 너무 좋았어요 존경합니다진한 눈물 흘리게해주고 많은걸 느꼈어요', 9], ['함정', '마동석님 멋있었는데 약간 잔인했었어요ㅠㅠ', 6], ['수색자', '전방 격오지에서 복무한 사람들은 어이가 없어서 헛웃음이 날 영화입니다.', 1], ['내안의 그놈', '이건 꼭 봐라 진짜 대작이다', 10], ['천문: 하늘에 묻는다', '너무 슬퍼요... 가슴이 먹먹해서 잠 다 잤어요ㅠ', 10], ['스마일', '기괴한 미소를 지으며 자신의 눈 앞에서 목숨을 끊는 환자를 목격한 정신과 의사 로즈. 일상을 덮친 공포에 발버둥치던 로즈는 이전에도 자신과 같은 일을 겪은 사람들이 있었고 그들 모두 끔찍한 죽음을 피할 수 없었다는 사실을 알게 된다.', 10], ['티켓 투 파라다이스', '이쁜 풍경에 발리 마려워지는 영화뻔한 로코물이라지만 뭐 어차피현실 우리네 사랑도 다 뻔한 거 아니냐며“좋은건 뒤로 미루면 안되지 “마지막 엔딩 장면이 넘 멋있었다크레딧 올라갈 때 촬영 비하인드 쿠키는 더 꿀잼', 8], ['대무가', '완전 쿨하고 힙하당', 10], ['인생은 아름다워', '기가막힌 연출이고 류승룡 염정화 아역배우 조연 다 연기가 너무 좋았어요 존경합니다진한 눈물 흘리게해주고 많은걸 느꼈어요', 9], ['함정', '마동석님 멋있었는데 약간 잔인했었어요ㅠㅠ', 6], ['수색자', '전방 격오지에서 복무한 사람들은 어이가 없어서 헛웃음이 날 영화입니다.', 1], ['내안의 그놈', '이건 꼭 봐라 진짜 대작이다', 10], ['천문: 하늘에 묻는다', '너무 슬퍼요... 가슴이 먹먹해서 잠 다 잤어요ㅠ', 10], ['스마일', '기괴한 미소를 지으며 자신의 눈 앞에서 목숨을 끊는 환자를 목격한 정신과 의사 로즈. 일상을 덮친 공포에 발버둥치던 로즈는 이전에도 자신과 같은 일을 겪은 사람들이 있었고 그들 모두 끔찍한 죽음을 피할 수 없었다는 사실을 알게 된다.', 10], ['티켓 투 파라다이스', '이쁜 풍경에 발리 마려워지는 영화뻔한 로코물이라지만 뭐 어차피현실 우리네 사랑도 다 뻔한 거 아니냐며“좋은건 뒤로 미루면 안되지 “마지막 엔딩 장면이 넘 멋있었다크레딧 올라갈 때 촬영 비하인드 쿠키는 더 꿀잼', 8], ['대무가', '완전 쿨하고 힙하당', 10], ['인생은 아름다워', '기가막힌 연출이고 류승룡 염정화 아역배우 조연 다 연기가 너무 좋았어요 존경합니다진한 눈물 흘리게해주고 많은걸 느꼈어요', 9], ['함정', '마동석님 멋있었는데 약간 잔인했었어요ㅠㅠ', 6], ['수색자', '전방 격오지에서 복무한 사람들은 어이가 없어서 헛웃음이 날 영화입니다.', 1], ['내안의 그놈', '이건 꼭 봐라 진짜 대작이다', 10] ...

# %%
#csv파일 
import csv

with open("samples.csv",'w') as fd:
  writer=csv.writer(fd,delimiter=',')
  writer.writerow(['movie', 'sentence','score'])#csv는 첫줄을 열이름으로 몰아붙이니까 미리 써놓기
  writer.writerows(review_data)
